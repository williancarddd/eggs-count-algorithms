# %%
import cv2
import os
import re
import pandas as pd
from datetime import datetime
from ultralytics import solutions
from skimage import exposure
import numpy as np
from typing import List, Tuple
from concurrent.futures import ThreadPoolExecutor
import logging

# Suprimir os logs do YOLO (ultralytics)
logging.getLogger("ultralytics").setLevel(logging.ERROR)

# Constantes
WINDOW_SIZE = 254
ROOT_FOLDER = "/media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms"
CSV_PATH = os.path.join(ROOT_FOLDER, "model_comparison.csv")
PATTERN = re.compile(r"paleta-(\d+)-(\d+)\.(png|jpg|jpeg)", re.IGNORECASE)

# Configurações
RUN_SINGLE_FOLDER_ONLY = False  # True para rodar só uma pasta específica
ESPECIFIC_FOLDER = "base-4"   # Nome da pasta específica se for rodar uma só

# Lista de modelos a serem testados
model_paths = [
    "/media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/yolo-train/eggs-scanner-image.v2i.yolov11/runs/detect/train3/weights/best-balanceado.pt",
]

class ImageProcessor:
    def __init__(self, model_path: str, window_size: int = WINDOW_SIZE) -> None:
        self.window_size = window_size
        self.model_path = model_path
        self.image = None
        self.processed_image = None
        self.processed_windows = []
        self.object_counts = []

    def load_image(self, image_path: str) -> np.ndarray:
        image = cv2.imread(image_path)
        if image is None:
            raise ValueError(f"Não foi possível carregar a imagem: {image_path}")
        return image

    def normalize_square(self, square: np.ndarray) -> np.ndarray:
        return exposure.adjust_gamma(square, gamma=1.5)

    def count_objects(self, square: np.ndarray) -> Tuple[int, np.ndarray]:
        region = [(0, 0), (WINDOW_SIZE, 0), (WINDOW_SIZE, WINDOW_SIZE), (0, WINDOW_SIZE)]
        counter = solutions.ObjectCounter(model=self.model_path, region=region, show=False, boxes=False)
        counted_image = counter.count(square)
        return len(counter.boxes), counted_image

    def process_single_window(self, window: np.ndarray, y: int, x: int, index: int) -> Tuple[int, np.ndarray, int, np.ndarray, int, int]:
        processed_window = self.normalize_square(window)
        object_count, counted_image = self.count_objects(processed_window)
        return index, processed_window, object_count, counted_image, y, x

    def apply_window_pipeline(self) -> None:
        if self.image is None:
            raise ValueError("Nenhuma imagem foi carregada para processamento.")

        img_height, img_width, channels = self.image.shape
        padded_height = ((img_height + self.window_size - 1) // self.window_size) * self.window_size
        padded_width = ((img_width + self.window_size - 1) // self.window_size) * self.window_size
        padded_image = np.zeros((padded_height, padded_width, channels), dtype=self.image.dtype)
        padded_image[:img_height, :img_width, :] = self.image
        processed_image = np.copy(padded_image)

        self.processed_windows.clear()
        self.object_counts.clear()

        tasks = []
        with ThreadPoolExecutor() as executor:
            for y in range(0, padded_height, self.window_size):
                for x in range(0, padded_width, self.window_size):
                    window = padded_image[y:y + self.window_size, x:x + self.window_size]
                    future = executor.submit(self.process_single_window, window, y, x, len(tasks))
                    tasks.append(future)

        results = sorted((future.result() for future in tasks), key=lambda r: r[0])
        for res in results:
            idx, processed_window, object_count, counted_image, y, x = res
            self.processed_windows.append(processed_window)
            self.object_counts.append(object_count)
            processed_image[y:y + self.window_size, x:x + self.window_size] = counted_image

        self.processed_image = processed_image[:img_height, :img_width]

    def process_folder(self, folder_path: str, model_name: str) -> List[Tuple[str, int, int, float]]:
        image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        start_time = datetime.now()
        results = []

        image_files.sort()

        for i, filename in enumerate(image_files):
            full_path = os.path.join(folder_path, filename)
            match = PATTERN.match(filename)
            real_eggs = int(match.group(2)) if match else "N/A"

            try:
                self.image = self.load_image(full_path)
            except ValueError as e:
                print(e)
                continue

            process_start_time = datetime.now()
            self.apply_window_pipeline()
            elapsed_time = (datetime.now() - process_start_time).total_seconds()

            total_objects = sum(self.object_counts)
            results.append((filename, real_eggs, total_objects, elapsed_time))

            if i < 2:
                processed_output_folder = os.path.join(folder_path, "processed")
                os.makedirs(processed_output_folder, exist_ok=True)
                output_image_path = os.path.join(processed_output_folder, f"processed_{model_name}_{filename}")
                cv2.imwrite(output_image_path, cv2.cvtColor(self.processed_image, cv2.COLOR_RGB2BGR))

        elapsed_total_time = (datetime.now() - start_time).total_seconds()
        timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        report_path = os.path.join(folder_path, f"report-{timestamp}-{model_name}.txt")

        with open(report_path, "w") as f:
            f.write("+===================================+\n")
            f.write("Filename - Ovos reais - Ovos contados\n")
            f.write(f"Modelo: {model_name}\n")
            f.write("+===================================+\n")
            for filename, real_eggs, counted_eggs, _ in results:
                f.write(f"{filename} - {real_eggs} - {counted_eggs}\n")
            f.write("+===================================+\n")
            f.write(f"Tempo total de execução: {elapsed_total_time:.2f}s\n")

        return results

def find_folders(root_path: str) -> List[str]:
    if RUN_SINGLE_FOLDER_ONLY and ESPECIFIC_FOLDER:
        folder_path = os.path.join(root_path, ESPECIFIC_FOLDER)
        return [folder_path] if os.path.isdir(folder_path) else []

    folders = []
    for d in sorted(os.listdir(root_path)):
        if d.startswith("base-"):
            match = re.match(r"base-(\d+)", d)
            if match:
                index = int(match.group(1))
                if 4 <= index <= 12:
                    folders.append(os.path.join(root_path, d))
    return folders

def update_csv(folder: str, results: List[Tuple[str, int, int, float]], model_name: str) -> None:
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    data = pd.DataFrame({
        "name_file": [folder] * len(results),
        "real_eggs_images": [result[1] for result in results],
        "counted_eggs_image": [result[2] for result in results],
        "model_name": [model_name] * len(results),
        "total_time": [result[3] for result in results],
        "image_name": [result[0] for result in results],
        "timestamp": [timestamp] * len(results)
    })

    if os.path.exists(CSV_PATH):
        data.to_csv(CSV_PATH, mode='a', header=False, index=False)
    else:
        data.to_csv(CSV_PATH, mode='w', header=True, index=False)

def main():
    folders = find_folders(ROOT_FOLDER)
    print(f"📂 Pastas encontradas: {len(folders)}")
    for model_path in model_paths:
        model_name = os.path.basename(model_path)
        print(f"\n🔍 Processando com modelo: {model_name}")
        processor = ImageProcessor(model_path)

        for folder in folders:
            print(f"📂 Pasta: {folder}")
            results = processor.process_folder(folder, model_name)
            update_csv(folder, results, model_name)

            for filename, real_eggs, total_counted, elapsed_time in results:
                print(f"🖼️  Imagem: {filename} | Real: {real_eggs} | Contado: {total_counted} | Tempo: {elapsed_time:.2f}s")

if __name__ == "__main__":
    main()
# Out:
# 📂 Pastas encontradas: 9
#
# 🔍 Processando com modelo: best-balanceado.pt
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-10
# 🖼️  Imagem: paleta-10-128.jpg | Real: 128 | Contado: 126 | Tempo: 40.82s
# 🖼️  Imagem: paleta-11-12.jpg | Real: 12 | Contado: 14 | Tempo: 35.04s
# 🖼️  Imagem: paleta-11-169.jpg | Real: 169 | Contado: 226 | Tempo: 35.18s
# 🖼️  Imagem: paleta-12-10.jpg | Real: 10 | Contado: 16 | Tempo: 35.15s
# 🖼️  Imagem: paleta-12-34.jpg | Real: 34 | Contado: 32 | Tempo: 34.06s
# 🖼️  Imagem: paleta-14-89.jpg | Real: 89 | Contado: 86 | Tempo: 35.06s
# 🖼️  Imagem: paleta-15-111.jpg | Real: 111 | Contado: 118 | Tempo: 34.96s
# 🖼️  Imagem: paleta-16-172.jpg | Real: 172 | Contado: 190 | Tempo: 33.95s
# 🖼️  Imagem: paleta-17-54.jpg | Real: 54 | Contado: 47 | Tempo: 35.07s
# 🖼️  Imagem: paleta-17-90.jpg | Real: 90 | Contado: 89 | Tempo: 33.70s
# 🖼️  Imagem: paleta-3-56.jpg | Real: 56 | Contado: 52 | Tempo: 34.87s
# 🖼️  Imagem: paleta-4-34.jpg | Real: 34 | Contado: 62 | Tempo: 35.07s
# 🖼️  Imagem: paleta-5-11.jpg | Real: 11 | Contado: 13 | Tempo: 33.33s
# 🖼️  Imagem: paleta-6-27.jpg | Real: 27 | Contado: 32 | Tempo: 33.07s
# 🖼️  Imagem: paleta-6-55.jpg | Real: 55 | Contado: 62 | Tempo: 41.75s
# 🖼️  Imagem: paleta-7-89.jpg | Real: 89 | Contado: 110 | Tempo: 34.42s
# 🖼️  Imagem: paleta-8-100.jpg | Real: 100 | Contado: 104 | Tempo: 34.47s
# 🖼️  Imagem: paleta-8-64.jpg | Real: 64 | Contado: 94 | Tempo: 33.00s
# 🖼️  Imagem: paleta-9-39.jpg | Real: 39 | Contado: 45 | Tempo: 32.79s
# 🖼️  Imagem: paleta-9-82.jpg | Real: 82 | Contado: 115 | Tempo: 34.24s
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-11
# 🖼️  Imagem: paleta-43-183.jpg | Real: 183 | Contado: 145 | Tempo: 34.34s
# 🖼️  Imagem: paleta-43-50.jpg | Real: 50 | Contado: 30 | Tempo: 38.09s
# 🖼️  Imagem: paleta-46-14.jpg | Real: 14 | Contado: 9 | Tempo: 32.71s
# 🖼️  Imagem: paleta-48-102.jpg | Real: 102 | Contado: 92 | Tempo: 33.99s
# 🖼️  Imagem: paleta-48-17.jpg | Real: 17 | Contado: 13 | Tempo: 34.18s
# 🖼️  Imagem: paleta-48-242.jpg | Real: 242 | Contado: 192 | Tempo: 33.33s

# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-5
# 🖼️  Imagem: paleta-14-18.jpg | Real: 18 | Contado: 18 | Tempo: 41.31s
# 🖼️  Imagem: paleta-185-103.jpg | Real: 103 | Contado: 42 | Tempo: 41.56s
# 🖼️  Imagem: paleta-191-34.jpg | Real: 34 | Contado: 47 | Tempo: 36.22s
# 🖼️  Imagem: paleta-201-46.jpg | Real: 46 | Contado: 48 | Tempo: 41.50s
# 🖼️  Imagem: paleta-228-152.jpg | Real: 152 | Contado: 137 | Tempo: 41.52s
# 🖼️  Imagem: paleta-254-47.jpg | Real: 47 | Contado: 45 | Tempo: 37.92s
# 🖼️  Imagem: paleta-256-12.jpg | Real: 12 | Contado: 9 | Tempo: 40.69s
# 🖼️  Imagem: paleta-38-16.jpg | Real: 16 | Contado: 16 | Tempo: 37.80s
# 🖼️  Imagem: paleta-404-44.jpg | Real: 44 | Contado: 29 | Tempo: 32.94s
# 🖼️  Imagem: paleta-81-8.jpg | Real: 8 | Contado: 5 | Tempo: 43.35s
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-6
# 🖼️  Imagem: paleta-067-23.jpg | Real: 23 | Contado: 14 | Tempo: 34.76s
# 🖼️  Imagem: paleta-109-41.jpg | Real: 41 | Contado: 39 | Tempo: 34.90s
# 🖼️  Imagem: paleta-187-32.jpg | Real: 32 | Contado: 29 | Tempo: 35.70s
# 🖼️  Imagem: paleta-291-58.jpg | Real: 58 | Contado: 39 | Tempo: 35.78s
# 🖼️  Imagem: paleta-34-59.jpg | Real: 59 | Contado: 47 | Tempo: 36.13s
# 🖼️  Imagem: paleta-352-4.jpg | Real: 4 | Contado: 3 | Tempo: 34.27s
# 🖼️  Imagem: paleta-43-108.jpg | Real: 108 | Contado: 51 | Tempo: 35.42s
# 🖼️  Imagem: paleta-51-7.jpg | Real: 7 | Contado: 3 | Tempo: 35.30s
# 🖼️  Imagem: paleta-61-15.jpg | Real: 15 | Contado: 14 | Tempo: 34.76s
# 🖼️  Imagem: paleta-78-60.jpg | Real: 60 | Contado: 49 | Tempo: 34.51s
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-7
# 🖼️  Imagem: paleta-1-112.jpg | Real: 112 | Contado: 130 | Tempo: 35.08s
# 🖼️  Imagem: paleta-10-4.jpg | Real: 4 | Contado: 8 | Tempo: 34.53s
# 🖼️  Imagem: paleta-11-47.jpg | Real: 47 | Contado: 74 | Tempo: 33.43s
# 🖼️  Imagem: paleta-12-93.jpg | Real: 93 | Contado: 142 | Tempo: 37.10s
# 🖼️  Imagem: paleta-13-129.jpg | Real: 129 | Contado: 150 | Tempo: 34.91s
# 🖼️  Imagem: paleta-14-114.jpg | Real: 114 | Contado: 128 | Tempo: 35.06s
# 🖼️  Imagem: paleta-15-15.jpg | Real: 15 | Contado: 21 | Tempo: 34.75s
# 🖼️  Imagem: paleta-16-95.jpg | Real: 95 | Contado: 113 | Tempo: 33.76s
# 🖼️  Imagem: paleta-17-24.jpg | Real: 24 | Contado: 32 | Tempo: 33.83s
# 🖼️  Imagem: paleta-2-4.jpg | Real: 4 | Contado: 11 | Tempo: 34.21s
# 🖼️  Imagem: paleta-5-20.jpg | Real: 20 | Contado: 31 | Tempo: 33.74s
# 🖼️  Imagem: paleta-7-53.jpg | Real: 53 | Contado: 71 | Tempo: 34.07s
# 🖼️  Imagem: paleta-9-13.jpg | Real: 13 | Contado: 16 | Tempo: 32.79s
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-8
# 🖼️  Imagem: paleta-110-50.jpg | Real: 50 | Contado: 40 | Tempo: 33.74s
# 🖼️  Imagem: paleta-144-29.jpg | Real: 29 | Contado: 15 | Tempo: 33.99s
# 🖼️  Imagem: paleta-177-24.jpg | Real: 24 | Contado: 25 | Tempo: 37.76s
# 🖼️  Imagem: paleta-186-136.jpg | Real: 136 | Contado: 133 | Tempo: 32.82s
# 🖼️  Imagem: paleta-282-16.jpg | Real: 16 | Contado: 22 | Tempo: 33.68s
# 🖼️  Imagem: paleta-290-18.jpg | Real: 18 | Contado: 23 | Tempo: 34.01s
# 🖼️  Imagem: paleta-329-20.jpg | Real: 20 | Contado: 43 | Tempo: 38.89s
# 🖼️  Imagem: paleta-33-12.jpg | Real: 12 | Contado: 14 | Tempo: 37.98s
# 🖼️  Imagem: paleta-37-22.jpg | Real: 22 | Contado: 14 | Tempo: 33.64s
# 🖼️  Imagem: paleta-87-55.jpg | Real: 55 | Contado: 42 | Tempo: 34.09s
# 📂 Pasta: /media/williancaddd/CODES/WORKSPACE-FIOTEC/eggs-count-algorithms/base-9
# 🖼️  Imagem: paleta-140-5.jpg | Real: 5 | Contado: 8 | Tempo: 33.91s
# 🖼️  Imagem: paleta-146-4.jpg | Real: 4 | Contado: 9 | Tempo: 32.89s
# 🖼️  Imagem: paleta-165-13.jpg | Real: 13 | Contado: 13 | Tempo: 33.82s
# 🖼️  Imagem: paleta-203-1.jpg | Real: 1 | Contado: 1 | Tempo: 34.20s
# 🖼️  Imagem: paleta-210-11.jpg | Real: 11 | Contado: 12 | Tempo: 33.99s
# 🖼️  Imagem: paleta-211-3.jpg | Real: 3 | Contado: 4 | Tempo: 33.92s
# 🖼️  Imagem: paleta-268-3.jpg | Real: 3 | Contado: 3 | Tempo: 32.50s
# 🖼️  Imagem: paleta-284-8.jpg | Real: 8 | Contado: 13 | Tempo: 33.99s
# 🖼️  Imagem: paleta-285-1.jpg | Real: 1 | Contado: 6 | Tempo: 34.15s
# 🖼️  Imagem: paleta-340-9.jpg | Real: 9 | Contado: 29 | Tempo: 32.95s
